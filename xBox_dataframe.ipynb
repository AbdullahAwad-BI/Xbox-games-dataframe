# %%
import pandas as pd

# %%
xbox=pd.read_csv(r"C:\Users\Rahhal\Desktop\DataSets\CSV Data\XboxOne_GameSales.csv")

# %%
xbox
# Out:
#      Pos                       Game    Year             Genre  \
# 0      1         Grand Theft Auto V  2014.0            Action
# 1      2  Call of Duty: Black Ops 3  2015.0           Shooter
# 2      3         Call of Duty: WWII  2017.0           Shooter
# 3      4      Red Dead Redemption 2  2018.0  Action-Adventure
# 4      5                  MineCraft  2014.0              Misc
# ..   ...                        ...     ...               ...
# 608  609                  Biomutant  2018.0            Action
# 609  610                  Biomutant  2019.0            Action
# 610  611                    de Blob  2017.0          Platform
# 611  612    Outcast: Second Contact  2017.0         Adventure
# 612  613                  Code Vein  2019.0            Action
#
#                       Publisher  North America  Europe  Japan  Rest of World  \
# 0                Rockstar Games           4.70    3.25   0.01           0.76
# ...

# %% [markdown]
# ## Displayed all Data

# %%
pd.options.display.max_rows=613

# %%
xbox
# Out:
#      Pos                                               Game    Year  \
# 0      1                                 Grand Theft Auto V  2014.0
# 1      2                          Call of Duty: Black Ops 3  2015.0
# 2      3                                 Call of Duty: WWII  2017.0
# 3      4                              Red Dead Redemption 2  2018.0
# 4      5                                          MineCraft  2014.0
# 5      6                     Call of Duty: Advanced Warfare  2014.0
# 6      7                                      Battlefield 1  2016.0
# 7      8                                          Fallout 4  2015.0
# 8      9                                  Halo 5: Guardians  2015.0
# 9     10                     Call of Duty: Infinite Warfare  2016.0
# 10    11                       Star Wars Battlefront (2015)  2015.0
# 11    12                                    Forza Horizon 3  2016.0
# 12    13                                            FIFA 17  2016.0
# ...

# %% [markdown]
# ## ## Filtering Xbox "Action Games" Released in 2014

# %%
f=xbox[(xbox["Year"]==2014)&(xbox["Genre"]=="Action")]

# %%
f
# Out:
#      Pos                                 Game    Year   Genre  \
# 0      1                   Grand Theft Auto V  2014.0  Action
# 14    15              Assassin's Creed: Unity  2014.0  Action
# 58    59       Middle-Earth: Shadow of Mordor  2014.0  Action
# 66    67                     Sunset Overdrive  2014.0  Action
# 131  132                              Thief 4  2014.0  Action
# 140  141         Lego Batman 3: Beyond Gotham  2014.0  Action
# 299  300          Dynasty Warriors 8: Empires  2014.0  Action
# 350  351                             Terraria  2014.0  Action
# 359  360                    Warriors Orochi 3  2014.0  Action
# 534  535                           Scalebound  2014.0  Action
# 537  538  Lara Croft and the Temple of Osiris  2014.0  Action
# 546  547           The Legend of Korra (2014)  2014.0  Action
#
#                                   Publisher  North America  Europe  Japan  \
# 0                            Rockstar Games           4.70    3.25   0.01
# ...

# %% [markdown]
# ## Filtering Xbox "Action Games" Released in 2014 & Publisher by "Rockstar Game"

# %%
f1=xbox[(xbox["Year"]==2014)&(xbox["Genre"]=="Action")&(xbox["Publisher"]=="Rockstar Games")]

# %%
f1
# Out:
#    Pos                Game    Year   Genre       Publisher  North America  \
# 0    1  Grand Theft Auto V  2014.0  Action  Rockstar Games            4.7
#
#    Europe  Japan  Rest of World  Global
# 0    3.25   0.01           0.76    8.72

# %% [markdown]
# ## Filtering Xbox Games Released from "2018" Onwards

# %%
f2=xbox[xbox["Year"]>=2018]

# %%
f2
# Out:
#      Pos                                               Game    Year  \
# 3      4                              Red Dead Redemption 2  2018.0
# 41    42                                          Far Cry 5  2018.0
# 75    76                                     Sea of Thieves  2018.0
# 77    78                              Monster Hunter: World  2018.0
# 122  123                              Dragon Ball Fighter Z  2018.0
# 141  142                                    EA Sports UFC 3  2018.0
# 160  161                                         The Crew 2  2018.0
# 185  186                                          A Way Out  2018.0
# 193  194                          Kingdom Come: Deliverance  2018.0
# 210  211                  Naruto to Boruto: Shinobi Striker  2018.0
# 246  247                                     Darksiders III  2018.0
# 247  248                                             Vampyr  2018.0
# 270  271                     Sword Art Online: Fatal Bullet  2018.0
# ...

# %% [markdown]
# ## Games that Published by "Rockstar Games"

# %%
g3=xbox[xbox["Publisher"]=="Rockstar Games"]

# %%
g3
# Out:
#      Pos                   Game    Year             Genre       Publisher  \
# 0      1     Grand Theft Auto V  2014.0            Action  Rockstar Games
# 3      4  Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 179  180             L.A. Noire  2017.0         Adventure  Rockstar Games
#
#      North America  Europe  Japan  Rest of World  Global
# 0             4.70    3.25   0.01           0.76    8.72
# 3             3.76    1.47   0.00           0.54    5.77
# 179           0.14    0.09   0.00           0.02    0.25

# %%
pwd
# Out:
# 'C:\\Users\\Rahhal'
